# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://free-proxy-list.net')
content = BeautifulSoup(res.text, 'lxml')
table = content.find('table')
rows = table.find_all('tr')
cols = [[col.text for col in row.find_all('td')] for row in rows]

proxies = []
proxy_index = 0

for col in cols:
    try:
        if col[4] == 'elite proxy' and col[6] == 'yes':
            proxies.append('https://' + col[0] + ':' + col[1])
    except:
        pass
    
def fetch(url, params):
    global proxy_index
    
    while proxy_index < len(proxies):
        try:
            print('Trying proxy:', proxies[proxy_index])
            res = requests.get(url, proxies={'https': proxies[proxy_index]}, params=params, timeout=5)
            return res
            
        except:
            print('Bad proxy...')
            proxy_index += 1

for page in range(0, 4):
    params = {'page': page}
    res = fetch('https://scrapingkungfu.herokuapp.com/api/request', params=params)
    proxy_index += 1
    print('ip', res.json()['ip'])
    print('url:', res.json()['url'])
# Out:
# Trying proxy: https://210.14.104.230:8080
# Bad proxy...
# Trying proxy: https://202.57.35.74:38629
# Bad proxy...
# Trying proxy: https://89.22.17.62:61616
# Bad proxy...
# Trying proxy: https://150.129.148.88:35101
# Bad proxy...
# Trying proxy: https://181.10.230.100:57148
# Bad proxy...
# Trying proxy: https://187.92.71.154:53281
# Bad proxy...
# Trying proxy: https://54.93.124.252:9300
# Bad proxy...
# Trying proxy: https://77.37.136.33:8118
# Bad proxy...
# Trying proxy: https://172.104.60.137:8080
# Bad proxy...
# Trying proxy: https://198.27.74.6:9300
# Bad proxy...
# Trying proxy: https://41.234.66.33:3128
# Bad proxy...
# Trying proxy: https://41.222.209.14:808
# Bad proxy...
# Trying proxy: https://180.211.192.61:8080
# Bad proxy...
# Trying proxy: https://188.156.240.240:8118
# Bad proxy...
# Trying proxy: https://58.84.170.228:53281
# Bad proxy...
# Trying proxy: https://45.76.174.251:1088
# Bad proxy...
# Trying proxy: https://23.226.117.143:8080
# Bad proxy...
# Trying proxy: https://23.224.22.89:59394
# Bad proxy...
# Trying proxy: https://23.224.22.28:59394
# Bad proxy...
# Trying proxy: https://3.92.190.74:59394
# Bad proxy...
# Trying proxy: https://95.25.41.172:55443
# Bad proxy...
# Trying proxy: https://119.28.131.202:59394
# Bad proxy...
# Trying proxy: https://41.222.209.12:808
# Bad proxy...
# Trying proxy: https://23.224.22.9:59394
# Bad proxy...
# Trying proxy: https://95.188.184.157:8080
# Bad proxy...
# Trying proxy: https://143.198.77.84:9300
# Bad proxy...
# Trying proxy: https://179.96.28.58:80
# Bad proxy...
# Trying proxy: https://80.59.199.212:8080
# Bad proxy...
# Trying proxy: https://190.104.3.244:6969
# Bad proxy...
# Trying proxy: https://119.28.91.152:59394
# Bad proxy...
# Trying proxy: https://119.28.132.148:59394
# Bad proxy...
# Trying proxy: https://101.33.34.223:59394
# Bad proxy...
# Trying proxy: https://101.32.219.80:59394
# Bad proxy...
# Trying proxy: https://23.224.22.26:59394
# Bad proxy...
# Trying proxy: https://43.128.26.102:59394
# Bad proxy...
# Trying proxy: https://142.154.124.228:8080
# Bad proxy...
# Trying proxy: https://103.52.153.102:59394
# Bad proxy...
# Trying proxy: https://93.158.214.155:3128
# Bad proxy...
# Trying proxy: https://23.224.22.18:59394
# Bad proxy...
# Trying proxy: https://170.106.184.46:59394
# Bad proxy...
# Trying proxy: https://93.158.214.154:3128
# Bad proxy...
# Trying proxy: https://85.195.104.71:80
# Bad proxy...
# Trying proxy: https://217.150.77.31:53281
# Bad proxy...
# Trying proxy: https://85.172.39.174:47326
# Bad proxy...
# Trying proxy: https://82.200.107.98:3128
# Bad proxy...
# Trying proxy: https://61.247.51.219:8080
# Bad proxy...
# Trying proxy: https://188.168.56.82:55443
# Bad proxy...
# Trying proxy: https://103.110.91.242:3128
# Bad proxy...
# Trying proxy: https://119.63.246.59:8118
# Bad proxy...
# Trying proxy: https://41.203.37.20:6969
# Bad proxy...
# Trying proxy: https://23.224.22.105:59394
# Bad proxy...
# Trying proxy: https://47.242.254.136:8119
# Bad proxy...
# Trying proxy: https://134.19.254.2:21231
# Bad proxy...
# Trying proxy: https://181.114.61.1:8085
# Bad proxy...
# Trying proxy: https://101.36.112.113:59394
# Bad proxy...
# Trying proxy: https://46.249.123.135:6565
# Bad proxy...
# Trying proxy: https://86.62.68.141:3128
# Bad proxy...
# Trying proxy: https://213.230.126.144:3128
# Bad proxy...
# Trying proxy: https://209.141.62.66:1080
# Bad proxy...
# Trying proxy: https://43.132.183.217:59394
# Bad proxy...
# Trying proxy: https://93.158.214.156:3128
# Bad proxy...
# Trying proxy: https://93.158.214.153:3128
# Bad proxy...
# Trying proxy: https://122.144.4.210:63123
# Bad proxy...
# Trying proxy: https://105.27.245.253:6969
# Bad proxy...
# Trying proxy: https://124.156.151.220:59394
# Bad proxy...
# Trying proxy: https://80.59.199.213:8080
# Bad proxy...
# Trying proxy: https://93.158.214.161:3128
# Bad proxy...
# Trying proxy: https://160.16.75.178:3128
# Bad proxy...
# Trying proxy: https://72.130.37.13:8080
# Bad proxy...
# Trying proxy: https://181.230.148.144:8080
# Bad proxy...
# Trying proxy: https://159.65.5.141:65534
# Bad proxy...
# Trying proxy: https://187.216.93.20:55443
# Bad proxy...
# Trying proxy: https://88.151.251.195:6969
# Bad proxy...
# Trying proxy: https://01.20.217.52:8080
# Bad proxy...
# Trying proxy: https://160.16.124.11:3128
# Bad proxy...
# Trying proxy: https://23.224.22.205:59394
# Bad proxy...
# Trying proxy: https://23.224.22.2:59394
# Bad proxy...
# Trying proxy: https://180.183.130.182:18080
# Bad proxy...
# Trying proxy: https://23.224.22.100:59394
# Bad proxy...
# Trying proxy: https://95.111.225.137:443
# Bad proxy...
# Trying proxy: https://194.44.150.250:55443
# Bad proxy...
# Trying proxy: https://88.255.102.98:8080
# Bad proxy...
# Trying proxy: https://213.230.69.193:3128
# Bad proxy...
# Trying proxy: https://187.216.90.46:53281
# Bad proxy...
# Trying proxy: https://46.28.109.236:8118
# Bad proxy...
# Trying proxy: https://131.108.118.27:8080
# Bad proxy...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-33ad6c0c6c83> in <module>
#      35     res = fetch('https://scrapingkungfu.herokuapp.com/api/request', params=params)
#      36     proxy_index += 1
# ---> 37     print('ip', res.json()['ip'])
#      38     print('url:', res.json()['url'])
#
# AttributeError: 'NoneType' object has no attribute 'json'
